# %% [markdown]
# <a href="https://colab.research.google.com/github/nurskurmanbekov/Career-Essentials-in-Data-Analysis-by-Microsoft-and-LinkedIn/blob/main/Untitled35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Addition library
import zipfile as zip
import collections
from datetime import datetime

# %%
zip.ZipFile('RUS_combined_data.zip').extractall()

# %%
df = pd.read_csv('RUS_combined_data.csv')

# %%
df.head()
# Out:
#        id car_brand car_model violation_date  \
# 0  134152    TOYOTA   MARK II        00:21.0
# 1   47014     LEXUS    LX 570        00:29.0
# 2    7448     HONDA       FIT        01:33.0
# 3  131275     HONDA       FIT        02:16.0
# 4  191395       BMW       728        02:22.0
#
#                                 crossroad_name  \
# 0  г. Бишкек, путепровод по пр. Байтик Баатыра
# 1   г. Бишкек, пересечение улиц Чуй - Ю.Фучика
# 2   г. Бишкек, пересечение улиц Чуй - Ю.Фучика
# 3          г. Бишкек, путепровод по пр. Манаса
# 4                 А/д Бишкек - Торугарт 12.9км
#
#                              violation_protocol_name  violation_ammount  \
# 0  Нарушение «превышение скорости» свыше 40 км/ч,...               5500
# 1            Невыполнение требований дорожных знаков               3000
# 2            Невыполнение требований дорожных знаков               3000
# 3  Нарушение «превышение скорости» свыше 20 км/ч,...               3000
# 4  Нарушение «превышение скорости» свыше 20 км/ч,...               3000
#
#         date      time
# 0   04/03/19  12:00 AM
# 1   04/03/19  12:00 AM
# 2   04/03/19  12:01 AM
# 3   04/03/19  12:02 AM
# 4   04/03/19  12:02 AM

# %%
df.columns
# Out:
# Index(['id', 'car_brand', 'car_model', 'violation_date', 'crossroad_name',
#        'violation_protocol_name', 'violation_ammount', 'date', 'time'],
#       dtype='object')

# %% [markdown]
# #### Анализ распространенных типов нарушений: в поисках паттернов
# #### Analyzing Common Types of Violations: Seeking Patterns

# %%
violation_types = [row['violation_protocol_name'] for i, row in df.iterrows()]

# %%
violation_counts = collections.Counter(violation_types)

# %%
most_common_violations = sorted(violation_counts.items(), key=lambda x: x[1], reverse=True)

# %%
most_common_violations_list = list(most_common_violations)

# %%
most_common_violations_list
# Out:
# [('Превышение установленной скорости движения на величину свыше 10км/ч, но не более 20 км/ч',
#   152334),
#  ('Невыполнение требований дорожных знаков', 107273),
#  ('Нарушение «превышение скорости» свыше 10 км/ч, но не более 20 км/ч', 83170),
#  ('Нарушение «превышение скорости» свыше 20 км/ч, но не более 40 км/ч', 62407),
#  ('Нарушение требований разметки проезжей части дороги', 52484),
#  ('Невыполнение требований ПДД об остановке перед стоп-линией, обозначенной дорожным знаком или разметкой проезжей части, при запрещающем сигнале светофора или жесте регулировщика',
#   41841),
#  ('Превышение установленной скорости движения на величину свыше 20км/ч, но не более 40 км/ч',
#   39460),
#  ('Нарушение правил обгона или маневрирования с выездом на полосу встречного движения',
#   13237),
#  ('Проезд на запрещенный сигнал светофора, либо жест регулировщика', 7968),
#  ('Нарушение «превышение скорости» свыше 40 км/ч, но не более 60 км/ч', 5139),
#  ('Превышение установленной скорости движения на величину свыше 40км/ч, но не более 60 км/ч',
#   3006),
#  ('Нарушение правил маневрирования', 2972),
#  ('Нарушение правил остановки либо стоянки', 1112),
#  ('Нарушение «превышение скорости» свыше 60 км/ч', 573),
#  ('Превышение установленной скорости движения на величину более 60км/ч', 361),
#  ('Нарушение правил остановки или стоянки, в том числе остановка или стоянка на полосе для маршрутных транспортных средств',
#   234),
#  ('Нарушение правил проезда пешеходных переходов, движение по тротуарам', 24),
#  ('Не выполнение требований дорожных знаков либо разметки проезжей части дороги',
#   14),
#  ('Нарушение требований дорожных знаков', 8),
#  ('Нарушение правил обгона или маневрирования без выезда на полосу встречного движения',
#   2)]

# %%
violation_dict = dict(most_common_violations_list)
violation_series = pd.Series(violation_dict)

# %%
sns.barplot(x=violation_series.index[:5], y=violation_series.values[:5])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Статистика нарушений: лидеры среди марок и моделей автомобилей
# #### Violation Statistics: Leading Car Makes and Models

# %% [markdown]
# ##### Car Models

# %%
brand_model_data = []
for i, row in df.iterrows():
    brand = row['car_brand']
    model = row['car_model']
    brand_model = "{} {}".format(brand, model)
    brand_model_data.append(brand_model)

# %%
brand_model_counts = collections.Counter(brand_model_data)
most_common_models = sorted(brand_model_counts.items(), key=lambda x: x[1], reverse=True)[:10]
print("The 10 most common models of cars that violate traffic rules are:")
for brand, count in most_common_models:
    print("* {} ({})".format(brand, count))
# Out:
# The 10 most common models of cars that violate traffic rules are:
# * HONDA FIT (26467)
# * TOYOTA CAMRY (26301)
# * HONDA ODYSSEY (16221)
# * HONDA STEPWGN (14074)
# * VOLKSWAGEN PASSAT (12574)
# * HONDA CR-V (12060)
# * LEXUS GX 470 (9850)
# * LEXUS LX 570 (8167)
# * LEXUS RX 300 (8047)
# * HONDA ACCORD (7988)

# %%
top_models = [models for models, _ in most_common_models[:10]]
models_counts = [count for _, count in most_common_models[:10]]

# %%
sns.set(style="whitegrid")
plt.pie(models_counts, labels=top_models, autopct='%1.1f%%', startangle=90)
plt.title("Top 10 Car Models in Traffic Violations")

plt.show()

# %% [markdown]
# ##### Brands

# %%
brand_counts = collections.Counter(df["car_brand"])

# %%
most_common_brands = sorted(brand_counts.items(), key=lambda x: x[1], reverse=True)[:10]
top_brands = [brand for brand, count in most_common_brands]
brand_counts = [count for _, count in most_common_brands]

# %%
print("The 10 most common car brands in traffic violations are:")
for brand, count in most_common_brands:
    print("* {} ({})".format(brand, count))
# Out:
# The 10 most common car brands in traffic violations are:
# * TOYOTA (126439)
# * HONDA (99203)
# * MERCEDES-BENZ (86335)
# * LEXUS (50274)
# * VOLKSWAGEN (33059)
# * NISSAN (20101)
# * MAZDA (20006)
# * BMW (19840)
# * SUBARU (18456)
# * AUDI (17171)

# %%
sns.set(style="whitegrid")
plt.pie(brand_counts, labels=top_brands, autopct='%1.1f%%', startangle=90)
plt.title("Top 10 Car Brands in Traffic Violations")
plt.show()

# %% [markdown]
# next

# %% [markdown]
# #### День недели с наибольшим количеством нарушений ПДД
# #### Day of the week with the highest number of traffic violations

# %%
data = df.copy()
data['date'] = data['date'].str.strip()
data['date'] = data['date'].apply(lambda x: datetime.strptime(x, "%d/%m/%y"))
sorted_df = data.sort_values(by='date')

# %%
data['time'].unique()
# Out:
# array(['12:00 AM', '12:01 AM', '12:02 AM', ..., '7:41 PM', '5:06 AM',
#        '6:29 AM'], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'car_brand', 'car_model', 'violation_date', 'crossroad_name',
#        'violation_protocol_name', 'violation_ammount', 'date', 'time'],
#       dtype='object')

# %%
data['date'].value_counts(ascending=False)
# Out:
# 2020-08-06    5179
# 2020-07-06    4946
# 2020-10-06    4931
# 2020-06-06    4921
# 2020-05-06    4838
#               ...
# 2019-03-13    1083
# 2019-03-17    1080
# 2021-02-01    1062
# 2019-03-28     778
# 2021-01-01     695
# Name: date, Length: 239, dtype: int64

# %%
sorted_df['date'].value_counts(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### Распределение нарушений ПДД по дням недели
# #### Distribution of traffic violations by day of the week

# %%
data['date'] = pd.to_datetime(data['date'])
top_10_violations = data['date'].dt.weekday.value_counts(ascending=False).head(10)
print(top_10_violations)
# Out:
# 3    88877
# 4    84866
# 6    83253
# 0    82670
# 2    81638
# 5    79695
# 1    72620
# Name: date, dtype: int64

# %%
top_10_violations
# Out:
# 3    88877
# 4    84866
# 6    83253
# 0    82670
# 2    81638
# 5    79695
# 1    72620
# Name: date, dtype: int64

# %%
plt.pie(top_10_violations, labels=['Четверг', 'Пятница', 'Воскресенье', 'Понедельник', 'Среда', 'Суббота', 'Вторник'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f36cd936350>,
#   <matplotlib.patches.Wedge at 0x7f36cd935cc0>,
#   <matplotlib.patches.Wedge at 0x7f36cd936800>,
#   <matplotlib.patches.Wedge at 0x7f36cd937460>,
#   <matplotlib.patches.Wedge at 0x7f36cd9340a0>,
#   <matplotlib.patches.Wedge at 0x7f36cd937bb0>,
#   <matplotlib.patches.Wedge at 0x7f36cd9342e0>],
#  [Text(0.9722378592435373, 0.5145420731617034, 'Четверг'),
#   Text(0.1453030029261719, 1.0903609665338525, 'Пятница'),
#   Text(-0.7800497019331964, 0.7755787919443978, 'Воскресенье'),
#   Text(-1.0912518283477546, -0.13845377252961694, 'Понедельник'),
#   Text(-0.5699904684815922, -0.9408033087952739, 'Среда'),
#   Text(0.36566777113933535, -1.0374425676392842, 'Суббота'),
#   Text(1.0141391441719971, -0.4260537480859538, 'Вторник')],
#  [Text(0.530311559587384, 0.2806593126336564, '15.5%'),
#   Text(0.07925618341427557, 0.5947423453821012, '14.8%'),
#   Text(-0.4254816555999253, 0.4230429774242169, '14.5%'),
#   Text(-0.595228270007866, -0.07552023956160922, '14.4%'),
#   Text(-0.3109038918990502, -0.5131654411610584, '14.2%'),
#   Text(0.19945514789418292, -0.5658777641668822, '13.9%'),
#   Text(0.5531668059119984, -0.23239295350142933, '12.7%')])

# %% [markdown]
# #### Топ 10 часто нарушаемых улицы
# #### Top 10 most frequently violated streets

# %%
df.head()
# Out:
#        id car_brand car_model violation_date  \
# 0  134152    TOYOTA   MARK II        00:21.0
# 1   47014     LEXUS    LX 570        00:29.0
# 2    7448     HONDA       FIT        01:33.0
# 3  131275     HONDA       FIT        02:16.0
# 4  191395       BMW       728        02:22.0
#
#                                 crossroad_name  \
# 0  г. Бишкек, путепровод по пр. Байтик Баатыра
# 1   г. Бишкек, пересечение улиц Чуй - Ю.Фучика
# 2   г. Бишкек, пересечение улиц Чуй - Ю.Фучика
# 3          г. Бишкек, путепровод по пр. Манаса
# 4                 А/д Бишкек - Торугарт 12.9км
#
#                              violation_protocol_name  violation_ammount  \
# 0  Нарушение «превышение скорости» свыше 40 км/ч,...               5500
# 1            Невыполнение требований дорожных знаков               3000
# 2            Невыполнение требований дорожных знаков               3000
# 3  Нарушение «превышение скорости» свыше 20 км/ч,...               3000
# 4  Нарушение «превышение скорости» свыше 20 км/ч,...               3000
#
#         date      time
# 0   04/03/19  12:00 AM
# 1   04/03/19  12:00 AM
# 2   04/03/19  12:01 AM
# 3   04/03/19  12:02 AM
# 4   04/03/19  12:02 AM

# %%
df['crossroad_name'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >
